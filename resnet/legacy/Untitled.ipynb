# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
image_path ='../../data/blood_cells/dataset2-master/images/TRAIN/LYMPHOCYTE/_0_1063.jpeg'

# %%
image_path
# Out:
# '../../data/blood_cells/dataset2-master/images/TRAIN/LYMPHOCYTE/_0_1063.jpeg'

# %%
img = plt.imread(image_path)

# %%
plt.imshow(img)
